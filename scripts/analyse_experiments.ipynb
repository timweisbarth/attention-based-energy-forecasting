# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Experiment 0

# %%
# Number of parameters [ftM, ftS] * 10^6
number_of_parameters = {
    "Autoformer":   [10.52, 10,51],
    "Informer":     [11.32, 11.31],
    "LSTM_min_24":  [4.25, 4.22],
    "LSTM_max_720": [5.32, 4.58],
    "Transformer":  [10.53, 10.52]
}

# %%
benchmark_table = pd.read_csv("./../results/benchmark_table_Exp0_metrics.csv", header=[0, 1], index_col=[0, 1])
epoch_time_table = pd.read_csv("./../results/benchmark_table_Exp0_epoch_time.csv", header=[0, 1], index_col=[0, 1])
dummy = benchmark_table["Dummy"]
print(dummy)
skill_table = 1 - benchmark_table/dummy

benchmark_table = benchmark_table.drop(columns="Dummy")
epoch_time_table = epoch_time_table.drop(columns="Dummy")
benchmark_table
# Out:
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_2519/345066400.py:4: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   benchmark_table = benchmark_table.drop(columns="Dummy")
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_2519/345066400.py:5: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   epoch_time_table = epoch_time_table.drop(columns="Dummy")
# Model          Autoformer        Informer        Transformer          LSTM  \
# Metric                MSE    MAE      MSE    MAE         MSE    MAE    MSE
# Target Horizon
# multi  24           0.285  0.342    0.221  0.284       0.231  0.301  0.218
#        48           0.437  0.417    0.333  0.367       0.355  0.365  0.336
#        96           0.581  0.505    0.464  0.468       0.460  0.429  0.445
#        192          0.587  0.508    0.528  0.492       0.502  0.439  0.505
#        336          0.586  0.507    0.514  0.496       0.510  0.453  0.520
#        720          0.659  0.551    0.545  0.477       0.618  0.491  0.519
# load   24           0.040  0.146    0.029  0.123       0.028  0.120  0.035
#        48           0.066  0.195    0.042  0.151       0.040  0.145  0.053
#        96           0.071  0.197    0.065  0.186       0.054  0.172  0.076
#        192          0.072  0.202    0.088  0.218       0.064  0.187  0.099
#        336          0.104  0.240    0.087  0.220       0.070  0.196  0.098
#        720          0.128  0.270    0.149  0.298       0.105  0.256  0.123
# solar  24           0.119  0.205    0.102  0.161       0.114  0.196  0.106
#        48           0.171  0.252    0.132  0.190       0.153  0.202  0.144
#        96           0.194  0.267    0.164  0.216       0.166  0.209  0.183
#        192          0.236  0.302    0.201  0.239       0.196  0.236  0.206
#        336          0.238  0.299    0.205  0.249       0.208  0.234  0.207
#        720          0.358  0.397    0.229  0.282       0.221  0.246  0.220
# wind   24           0.663  0.622    0.480  0.517       0.499  0.511  0.452
#        48           1.034  0.802    0.796  0.682       0.793  0.676  0.796
#        96           1.339  0.936    1.032  0.797       1.090  0.796  1.053
#        192          1.417  0.942    1.177  0.876       1.412  0.905  1.295
#        336          1.420  0.957    1.264  0.906       1.457  0.940  1.074
#        720          1.495  0.958    1.329  0.940       1.284  0.899  1.197
#
# Model                 XGBoost        Linear Regression
# Metric            MAE     MSE    MAE               MSE    MAE
# Target Horizon
# multi  24       0.292   0.233  0.276             0.221  0.305
#        48       0.374   0.357  0.352             0.327  0.379
#        96       0.439   0.452  0.403             0.412  0.429
#        192      0.474   0.510  0.431             0.471  0.463
#        336      0.477   0.535  0.447             0.505  0.487
#        720      0.498   0.556  0.463             0.532  0.512
# load   24       0.126   0.036  0.134             0.103  0.236
#        48       0.161   0.055  0.169             0.125  0.267
#        96       0.195   0.071  0.192             0.126  0.262
#        192      0.220   0.082  0.206             0.126  0.256
#        336      0.225   0.090  0.216             0.134  0.267
#        720      0.262   0.108  0.240             0.148  0.287
# solar  24       0.172   0.151  0.183             0.117  0.195
#        48       0.205   0.204  0.215             0.148  0.225
#        96       0.237   0.242  0.237             0.182  0.255
#        192      0.254   0.262  0.250             0.213  0.280
#        336      0.257   0.280  0.260             0.233  0.298
#        720      0.269   0.294  0.270             0.269  0.333
# wind   24       0.488   0.530  0.516             0.448  0.491
#        48       0.679   0.839  0.680             0.715  0.654
#        96       0.804   1.064  0.786             0.936  0.781
#        192      0.919   1.202  0.845             1.082  0.863
#        336      0.832   1.252  0.870             1.149  0.901
#        720      0.876   1.288  0.885             1.183  0.921

# %%
epoch_time_table
# Out:
# Model          Autoformer           Informer           Transformer            \
# Metric             epochs time[min]   epochs time[min]      epochs time[min]
# Target Horizon
# multi  24             7.0         9      8.0         6         4.0         3
#        48             4.0         5      5.0         4         4.0         3
#        96             4.0         6      4.0         4         4.0         3
#        192            5.0        10      5.0         6         4.0         4
#        336            5.0        12      4.0         5         4.0         5
#        720            4.0        16      6.0        11         5.0        12
# load   24            10.0        13      9.0         7         8.0         5
#        48             8.0        10     10.0         8         5.0         3
#        96             8.0        12     10.0        10         6.0         4
#        192            8.0        15      9.0        10         5.0         5
#        336            5.0        12      6.0         8         4.0         5
#        720            6.0        24      4.0         8         4.0        10
# solar  24             9.0        11     10.0         8         5.0         3
#        48             4.0         5     10.0         8         6.0         4
#        96             7.0        11      9.0         9         4.0         3
#        192            9.0        17      7.0         8         5.0         5
#        336            7.0        17      6.0         8         4.0         5
#        720            6.0        23      4.0         8         4.0         9
# wind   24             5.0         6      5.0         4         4.0         3
#        48             4.0         5      5.0         4         4.0         3
#        96             4.0         6      5.0         5         4.0         3
#        192            6.0        11      5.0         5         4.0         4
#        336            4.0        10      5.0         7         4.0         5
#        720            4.0        15      4.0         7         4.0         9
#
# Model            LSTM           XGBoost           Linear Regression
# Metric         epochs time[min]  epochs time[min]            epochs time[min]
# Target Horizon
# multi  24         4.0         1     NaN         0               NaN         0
#        48         4.0         1     NaN         0               NaN         0
#        96         4.0         2     NaN         1               NaN         0
#        192        4.0         2     NaN         2               NaN         0
#        336        5.0         3     NaN         3               NaN         0
#        720        4.0         3     NaN         7               NaN         0
# load   24         9.0         4     NaN         0               NaN         0
#        48         5.0         2     NaN         0               NaN         0
#        96         4.0         2     NaN         0               NaN         0
#        192        5.0         3     NaN         1               NaN         0
#        336        6.0         3     NaN         1               NaN         0
#        720        4.0         2     NaN         2               NaN         0
# solar  24         6.0         2     NaN         0               NaN         0
#        48         6.0         2     NaN         0               NaN         0
#        96         5.0         3     NaN         0               NaN         0
#        192        4.0         2     NaN         1               NaN         0
#        336        5.0         3     NaN         1               NaN         0
#        720        4.0         2     NaN         2               NaN         0
# wind   24         4.0         2     NaN         0               NaN         0
#        48         4.0         1     NaN         0               NaN         0
#        96         4.0         2     NaN         0               NaN         0
#        192        4.0         2     NaN         0               NaN         0
#        336        4.0         2     NaN         1               NaN         0
#        720        4.0         2     NaN         2               NaN         0

# %%
targets = ["multi", "load", "solar", "wind"] 
horizons = ['24', '48', '96', '192', '336', '720']  
models = ['Autoformer', 'Informer', 'Transformer', "LSTM", "XGBoost", "Linear Regression", "Dummy"]  
metrics = ['MSE', 'MAE']  



bms = []
bms_et = []
for target in targets:
    bm = benchmark_table.xs(target, level=0, axis=0)
    bm_mse = bm.xs('MSE', level=1, axis=1)
    bm_mae = bm.xs('MAE', level=1, axis=1)
    bms.append((bm_mse, bm_mae))

    bm_et = epoch_time_table.xs(target, level=0, axis=0)
    bm_e = bm_et.xs('epochs', level=1, axis=1)
    bm_t = bm_et.xs('time[min]', level=1, axis=1)
    bms_et.append((bm_e, bm_t))



# Plot mse for multi target
bms[0][0]
# Out:
# Model    Autoformer  Informer  Transformer   LSTM  XGBoost  Linear Regression
# Horizon
# 24            0.285     0.221        0.231  0.218    0.233              0.221
# 48            0.437     0.333        0.355  0.336    0.357              0.327
# 96            0.581     0.464        0.460  0.445    0.452              0.412
# 192           0.587     0.528        0.502  0.505    0.510              0.471
# 336           0.586     0.514        0.510  0.520    0.535              0.505
# 720           0.659     0.545        0.618  0.519    0.556              0.532

# %%
fig, ax = plt.subplots(2, 2, figsize=(6, 6))
# Define a list of colors for each model
colors = ["#1f77b4", "#17becf", "#2ca02c", "#d62728", "#ff7f0e", "#7f7f7f"] # purple: "#9467bd"
#colors= ["#1f77b4", "#17becf", "#2ca02c", "#e377c2","#bcbd22", "#7f7f7f"]

for i, (bm_mse, bm_mae) in enumerate(bms):
    row, col = divmod(i, 2)
    #print(bm_mse.shape)
    #print(len(colors))
    #ax[row][col].plot(bm_mse, color=colors)
    for j in range(bm_mse.shape[1]):  # Iterate over the columns of bm_mse
        #print(bm_mse.shape)
        #print(type(bm_mse))
        ax[row][col].plot(bm_mse.iloc[:, j], color=colors[j])
    ax[row][col].set_title('MSE ' + targets[i])
fig.legend(models[:-1], loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=4)
fig.tight_layout()

# %%
import numpy as np


# For each target
for i, ((bm_mse, bm_mae),(bm_e, bm_t)) in enumerate(zip(bms, bms_et)):
    
    # For each horizon: Plot mse vs time for all models
    fig, ax = plt.subplots(2,3, figsize=(8, 6))
    for j, horizon in enumerate(horizons):
        row, col = divmod(j, 3)
        ax[row][col].scatter(bm_t.iloc[j].values, bm_mse.iloc[j].values, c=colors)
        ax[row][col].set_title('MSE ' + targets[i] + ', horizon ' + horizons[j])
    #fig.legend(models[:-1], loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=4)
