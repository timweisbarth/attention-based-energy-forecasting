# %% [markdown]
# # Experiment 0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Number of parameters [multivariate forecast, univariate forecast] * 10^6
number_of_parameters = {
    "Autoformer":   [10.52, 10,51],
    "Informer":     [11.32, 11.31],
    "LSTM_min_24":  [4.25, 4.22],
    "LSTM_max_720": [5.32, 4.58],
    "Transformer":  [10.53, 10.52]
}
targets = ["multi", "load", "solar", "wind"] 
horizons = ['24', '48', '96', '192', '336', '720']  
models = ['Autoformer', 'Informer', 'Transformer', "LSTM", "XGBoost", "Linear Regression", "Dummy"]  
metrics = ['MSE', 'MAE']

# %% [markdown]
# ## Import data and plot all benchmark results

# %%
benchmark_table_with_dummy = pd.read_csv("./../results/benchmark_table_Exp0_metrics.csv", header=[0, 1], index_col=[0, 1])
epoch_time_table = pd.read_csv("./../results/benchmark_table_Exp0_epoch_time.csv", header=[0, 1], index_col=[0, 1])

skill_table = 1 - benchmark_table_with_dummy/ benchmark_table_with_dummy["Dummy"]

benchmark_table = benchmark_table_with_dummy.drop(columns="Dummy")
epoch_time_table = epoch_time_table.drop(columns="Dummy")
display(benchmark_table_with_dummy)
# Out:
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_6376/2711800682.py:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   benchmark_table = benchmark_table_with_dummy.drop(columns="Dummy")
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_6376/2711800682.py:7: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   epoch_time_table = epoch_time_table.drop(columns="Dummy")
# Model          Autoformer        Informer        Transformer          LSTM  \
# Metric                MSE    MAE      MSE    MAE         MSE    MAE    MSE
# Target Horizon
# multi  24           0.285  0.342    0.221  0.284       0.231  0.301  0.218
#        48           0.437  0.417    0.333  0.367       0.355  0.365  0.336
#        96           0.581  0.505    0.464  0.468       0.460  0.429  0.445
#        192          0.587  0.508    0.528  0.492       0.502  0.439  0.505
#        336          0.586  0.507    0.514  0.496       0.510  0.453  0.520
#        720          0.659  0.551    0.545  0.477       0.618  0.491  0.519
# load   24           0.040  0.146    0.029  0.123       0.028  0.120  0.035
#        48           0.066  0.195    0.042  0.151       0.040  0.145  0.053
#        96           0.071  0.197    0.065  0.186       0.054  0.172  0.076
#        192          0.072  0.202    0.088  0.218       0.064  0.187  0.099
#        336          0.104  0.240    0.087  0.220       0.070  0.196  0.098
#        720          0.128  0.270    0.149  0.298       0.105  0.256  0.123
# solar  24           0.119  0.205    0.102  0.161       0.114  0.196  0.106
#        48           0.171  0.252    0.132  0.190       0.153  0.202  0.144
#        96           0.194  0.267    0.164  0.216       0.166  0.209  0.183
#        192          0.236  0.302    0.201  0.239       0.196  0.236  0.206
#        336          0.238  0.299    0.205  0.249       0.208  0.234  0.207
#        720          0.358  0.397    0.229  0.282       0.221  0.246  0.220
# wind   24           0.663  0.622    0.480  0.517       0.499  0.511  0.452
#        48           1.034  0.802    0.796  0.682       0.793  0.676  0.796
#        96           1.339  0.936    1.032  0.797       1.090  0.796  1.053
#        192          1.417  0.942    1.177  0.876       1.412  0.905  1.295
#        336          1.420  0.957    1.264  0.906       1.457  0.940  1.074
#        720          1.495  0.958    1.329  0.940       1.284  0.899  1.197
#
# Model                 XGBoost        Linear Regression         Dummy
# Metric            MAE     MSE    MAE               MSE    MAE    MSE    MAE
# Target Horizon
# multi  24       0.292   0.233  0.276             0.221  0.305  0.864  0.656
#        48       0.374   0.357  0.352             0.327  0.379  0.863  0.655
#        96       0.439   0.452  0.403             0.412  0.429  0.861  0.654
#        192      0.474   0.510  0.431             0.471  0.463  0.858  0.653
#        336      0.477   0.535  0.447             0.505  0.487  0.856  0.652
#        720      0.498   0.556  0.463             0.532  0.512  0.851  0.649
# load   24       0.126   0.036  0.134             0.103  0.236  0.496  0.563
#        48       0.161   0.055  0.169             0.125  0.267  0.494  0.562
#        96       0.195   0.071  0.192             0.126  0.262  0.493  0.561
#        192      0.220   0.082  0.206             0.126  0.256  0.492  0.560
#        336      0.225   0.090  0.216             0.134  0.267  0.490  0.559
#        720      0.262   0.108  0.240             0.148  0.287  0.487  0.556
# solar  24       0.172   0.151  0.183             0.117  0.195  0.766  0.513
#        48       0.205   0.204  0.215             0.148  0.225  0.766  0.513
#        96       0.237   0.242  0.237             0.182  0.255  0.766  0.513
#        192      0.254   0.262  0.250             0.213  0.280  0.766  0.513
#        336      0.257   0.280  0.260             0.233  0.298  0.766  0.513
#        720      0.269   0.294  0.270             0.269  0.333  0.764  0.511
# wind   24       0.488   0.530  0.516             0.448  0.491  1.331  0.892
#        48       0.679   0.839  0.680             0.715  0.654  1.329  0.891
#        96       0.804   1.064  0.786             0.936  0.781  1.323  0.889
#        192      0.919   1.202  0.845             1.082  0.863  1.316  0.886
#        336      0.832   1.252  0.870             1.149  0.901  1.313  0.884
#        720      0.876   1.288  0.885             1.183  0.921  1.303  0.880

# %% [markdown]
# # Plot again but highlight best value

# %%
def highlight_min(s):
    '''
    Highlight the minimum in a Series green.
    '''
    s_mse = s.xs("MSE", axis=0, level=1)
    is_min_mse = s_mse == s_mse.min()
    s_mae = s.xs("MAE", axis=0, level=1)
    is_min_mae = s_mae == s_mae.min()

    is_min = s.copy()
    
    is_min.loc[:,"MSE"] = is_min_mse.values
    is_min.loc[:,"MAE"] = is_min_mae.values

    return ['background-color: green' if v else '' for v in is_min]

styled_df = benchmark_table.style.apply(highlight_min, axis=1)
styled_df
# Out:
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_6376/81131224.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False False False  True False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   is_min.loc[:,"MSE"] = is_min_mse.values
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_6376/81131224.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False False False False False  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   is_min.loc[:,"MSE"] = is_min_mse.values
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_6376/81131224.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False False  True False False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   is_min.loc[:,"MSE"] = is_min_mse.values
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_6376/81131224.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False  True False False False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   is_min.loc[:,"MSE"] = is_min_mse.values
# <style type="text/css">
# #T_80f0d_row0_col6, #T_80f0d_row0_col9, #T_80f0d_row1_col9, #T_80f0d_row1_col10, #T_80f0d_row2_col9, #T_80f0d_row2_col10, #T_80f0d_row3_col9, #T_80f0d_row3_col10, #T_80f0d_row4_col9, #T_80f0d_row4_col10, #T_80f0d_row5_col6, #T_80f0d_row5_col9, #T_80f0d_row6_col4, #T_80f0d_row6_col5, #T_80f0d_row7_col4, #T_80f0d_row7_col5, #T_80f0d_row8_col4, #T_80f0d_row8_col5, #T_80f0d_row9_col4, #T_80f0d_row9_col5, #T_80f0d_row10_col4, #T_80f0d_row10_col5, #T_80f0d_row11_col4, #T_80f0d_row11_col9, #T_80f0d_row12_col2, #T_80f0d_row12_col3, #T_80f0d_row13_col2, #T_80f0d_row13_col3, #T_80f0d_row14_col2, #T_80f0d_row14_col5, #T_80f0d_row15_col4, #T_80f0d_row15_col5, #T_80f0d_row16_col2, #T_80f0d_row16_col5, #T_80f0d_row17_col5, #T_80f0d_row17_col6, #T_80f0d_row18_col7, #T_80f0d_row18_col10, #T_80f0d_row19_col10, #T_80f0d_row19_col11, #T_80f0d_row20_col10, #T_80f0d_row20_col11, #T_80f0d_row21_col9, #T_80f0d_row21_col10, #T_80f0d_row22_col6, #T_80f0d_row22_col7, #T_80f0d_row23_col7, #T_80f0d_row23_col10 {
#   background-color: green;
# }
# </style>
# <table id="T_80f0d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Model</th>
#       <th id="T_80f0d_level0_col0" class="col_heading level0 col0" colspan="2">Autoformer</th>
#       <th id="T_80f0d_level0_col2" class="col_heading level0 col2" colspan="2">Informer</th>
#       <th id="T_80f0d_level0_col4" class="col_heading level0 col4" colspan="2">Transformer</th>
#       <th id="T_80f0d_level0_col6" class="col_heading level0 col6" colspan="2">LSTM</th>
#       <th id="T_80f0d_level0_col8" class="col_heading level0 col8" colspan="2">XGBoost</th>
#       <th id="T_80f0d_level0_col10" class="col_heading level0 col10" colspan="2">Linear Regression</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_80f0d_level1_col0" class="col_heading level1 col0" >MSE</th>
#       <th id="T_80f0d_level1_col1" class="col_heading level1 col1" >MAE</th>
#       <th id="T_80f0d_level1_col2" class="col_heading level1 col2" >MSE</th>
#       <th id="T_80f0d_level1_col3" class="col_heading level1 col3" >MAE</th>
#       <th id="T_80f0d_level1_col4" class="col_heading level1 col4" >MSE</th>
#       <th id="T_80f0d_level1_col5" class="col_heading level1 col5" >MAE</th>
#       <th id="T_80f0d_level1_col6" class="col_heading level1 col6" >MSE</th>
#       <th id="T_80f0d_level1_col7" class="col_heading level1 col7" >MAE</th>
#       <th id="T_80f0d_level1_col8" class="col_heading level1 col8" >MSE</th>
#       <th id="T_80f0d_level1_col9" class="col_heading level1 col9" >MAE</th>
#       <th id="T_80f0d_level1_col10" class="col_heading level1 col10" >MSE</th>
#       <th id="T_80f0d_level1_col11" class="col_heading level1 col11" >MAE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Target</th>
#       <th class="index_name level1" >Horizon</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80f0d_level0_row0" class="row_heading level0 row0" rowspan="6">multi</th>
#       <th id="T_80f0d_level1_row0" class="row_heading level1 row0" >24</th>
#       <td id="T_80f0d_row0_col0" class="data row0 col0" >0.285000</td>
#       <td id="T_80f0d_row0_col1" class="data row0 col1" >0.342000</td>
#       <td id="T_80f0d_row0_col2" class="data row0 col2" >0.221000</td>
#       <td id="T_80f0d_row0_col3" class="data row0 col3" >0.284000</td>
#       <td id="T_80f0d_row0_col4" class="data row0 col4" >0.231000</td>
#       <td id="T_80f0d_row0_col5" class="data row0 col5" >0.301000</td>
#       <td id="T_80f0d_row0_col6" class="data row0 col6" >0.218000</td>
#       <td id="T_80f0d_row0_col7" class="data row0 col7" >0.292000</td>
#       <td id="T_80f0d_row0_col8" class="data row0 col8" >0.233000</td>
#       <td id="T_80f0d_row0_col9" class="data row0 col9" >0.276000</td>
#       <td id="T_80f0d_row0_col10" class="data row0 col10" >0.221000</td>
#       <td id="T_80f0d_row0_col11" class="data row0 col11" >0.305000</td>
#     </tr>
#     <tr>
#       <th id="T_80f0d_level1_row1" class="row_heading level1 row1" >48</th>
#       <td id="T_80f0d_row1_col0" class="data row1 col0" >0.437000</td>
#       <td id="T_80f0d_row1_col1" class="data row1 col1" >0.417000</td>
#       <td id="T_80f0d_row1_col2" class="data row1 col2" >0.333000</td>
#       <td id="T_80f0d_row1_col3" class="data row1 col3" >0.367000</td>
#       <td id="T_80f0d_row1_col4" class="data row1 col4" >0.355000</td>
#       <td id="T_80f0d_row1_col5" class="data row1 col5" >0.365000</td>
#       <td id="T_80f0d_row1_col6" class="data row1 col6" >0.336000</td>
#       <td id="T_80f0d_row1_col7" class="data row1 col7" >0.374000</td>
#       <td id="T_80f0d_row1_col8" class="data row1 col8" >0.357000</td>
#       <td id="T_80f0d_row1_col9" class="data row1 col9" >0.352000</td>
#       <td id="T_80f0d_row1_col10" class="data row1 col10" >0.327000</td>
#       <td id="T_80f0d_row1_col11" class="data row1 col11" >0.379000</td>
#     </tr>
#     <tr>
#       <th id="T_80f0d_level1_row2" class="row_heading level1 row2" >96</th>
#       <td id="T_80f0d_row2_col0" class="data row2 col0" >0.581000</td>
#       <td id="T_80f0d_row2_col1" class="data row2 col1" >0.505000</td>
#       <td id="T_80f0d_row2_col2" class="data row2 col2" >0.464000</td>
#       <td id="T_80f0d_row2_col3" class="data row2 col3" >0.468000</td>
#       <td id="T_80f0d_row2_col4" class="data row2 col4" >0.460000</td>
#       <td id="T_80f0d_row2_col5" class="data row2 col5" >0.429000</td>
#       <td id="T_80f0d_row2_col6" class="data row2 col6" >0.445000</td>
#       <td id="T_80f0d_row2_col7" class="data row2 col7" >0.439000</td>
#       <td id="T_80f0d_row2_col8" class="data row2 col8" >0.452000</td>
#       <td id="T_80f0d_row2_col9" class="data row2 col9" >0.403000</td>
#       <td id="T_80f0d_row2_col10" class="data row2 col10" >0.412000</td>
#       <td id="T_80f0d_row2_col11" class="data row2 col11" >0.429000</td>
#     </tr>
#     <tr>
#       <th id="T_80f0d_level1_row3" class="row_heading level1 row3" >192</th>
#       <td id="T_80f0d_row3_col0" class="data row3 col0" >0.587000</td>
#       <td id="T_80f0d_row3_col1" class="data row3 col1" >0.508000</td>
#       <td id="T_80f0d_row3_col2" class="data row3 col2" >0.528000</td>
#       <td id="T_80f0d_row3_col3" class="data row3 col3" >0.492000</td>
#       <td id="T_80f0d_row3_col4" class="data row3 col4" >0.502000</td>
#       <td id="T_80f0d_row3_col5" class="data row3 col5" >0.439000</td>
#       <td id="T_80f0d_row3_col6" class="data row3 col6" >0.505000</td>
#       <td id="T_80f0d_row3_col7" class="data row3 col7" >0.474000</td>
#       <td id="T_80f0d_row3_col8" class="data row3 col8" >0.510000</td>
#       <td id="T_80f0d_row3_col9" class="data row3 col9" >0.431000</td>
#       <td id="T_80f0d_row3_col10" class="data row3 col10" >0.471000</td>
#       <td id="T_80f0d_row3_col11" class="data row3 col11" >0.463000</td>
#     </tr>
#     <tr>
#       <th id="T_80f0d_level1_row4" class="row_heading level1 row4" >336</th>
#       <td id="T_80f0d_row4_col0" class="data row4 col0" >0.586000</td>
#       <td id="T_80f0d_row4_col1" class="data row4 col1" >0.507000</td>
#       <td id="T_80f0d_row4_col2" class="data row4 col2" >0.514000</td>
#       <td id="T_80f0d_row4_col3" class="data row4 col3" >0.496000</td>
#       <td id="T_80f0d_row4_col4" class="data row4 col4" >0.510000</td>
#       <td id="T_80f0d_row4_col5" class="data row4 col5" >0.453000</td>
#       <td id="T_80f0d_row4_col6" class="data row4 col6" >0.520000</td>
#       <td id="T_80f0d_row4_col7" class="data row4 col7" >0.477000</td>
#       <

# %% [markdown]
# ## Skill table for dummy, where skill = 1 - MSE_model / MSE_dummy

# %%
def color_scale(val):
    # Normalize the value to the range [0, 1] from the original range of [-1, 1]
    normalized = (val + 0.7) / 2
    # Convert to RGB color
    red = 255 * (1 - normalized)
    green = 255 * normalized
    blue = 0
    return f'background-color: rgb({int(red)}, {int(green)}, {blue})'

styled_df = skill_table.style.applymap(color_scale)
styled_df
# Out:
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_6376/4123917723.py:13: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = skill_table.style.applymap(color_scale)
# <style type="text/css">
# #T_f57c0_row0_col0, #T_f57c0_row8_col3, #T_f57c0_row9_col5, #T_f57c0_row12_col7 {
#   background-color: rgb(80, 174, 0);
# }
# #T_f57c0_row0_col1, #T_f57c0_row2_col6, #T_f57c0_row11_col11, #T_f57c0_row14_col1 {
#   background-color: rgb(104, 150, 0);
# }
# #T_f57c0_row0_col2, #T_f57c0_row0_col6, #T_f57c0_row0_col10, #T_f57c0_row7_col10, #T_f57c0_row8_col10, #T_f57c0_row9_col10, #T_f57c0_row11_col6, #T_f57c0_row14_col0, #T_f57c0_row15_col4 {
#   background-color: rgb(70, 184, 0);
# }
# #T_f57c0_row0_col3, #T_f57c0_row11_col9 {
#   background-color: rgb(93, 161, 0);
# }
# #T_f57c0_row0_col4, #T_f57c0_row0_col8, #T_f57c0_row7_col3, #T_f57c0_row13_col8, #T_f57c0_row15_col6, #T_f57c0_row16_col2, #T_f57c0_row16_col4, #T_f57c0_row16_col6 {
#   background-color: rgb(72, 182, 0);
# }
# #T_f57c0_row0_col5, #T_f57c0_row9_col11, #T_f57c0_row11_col5, #T_f57c0_row15_col5, #T_f57c0_row16_col5 {
#   background-color: rgb(96, 158, 0);
# }
# #T_f57c0_row0_col7 {
#   background-color: rgb(95, 159, 0);
# }
# #T_f57c0_row0_col9, #T_f57c0_row6_col11, #T_f57c0_row13_col9, #T_f57c0_row14_col3 {
#   background-color: rgb(91, 163, 0);
# }
# #T_f57c0_row0_col11, #T_f57c0_row8_col11, #T_f57c0_row14_col7, #T_f57c0_row14_col9, #T_f57c0_row15_col3, #T_f57c0_row17_col0 {
#   background-color: rgb(97, 157, 0);
# }
# #T_f57c0_row0_col12, #T_f57c0_row0_col13, #T_f57c0_row1_col12, #T_f57c0_row1_col13, #T_f57c0_row2_col12, #T_f57c0_row2_col13, #T_f57c0_row3_col12, #T_f57c0_row3_col13, #T_f57c0_row4_col12, #T_f57c0_row4_col13, #T_f57c0_row5_col12, #T_f57c0_row5_col13, #T_f57c0_row6_col12, #T_f57c0_row6_col13, #T_f57c0_row7_col12, #T_f57c0_row7_col13, #T_f57c0_row8_col12, #T_f57c0_row8_col13, #T_f57c0_row9_col12, #T_f57c0_row9_col13, #T_f57c0_row10_col12, #T_f57c0_row10_col13, #T_f57c0_row11_col12, #T_f57c0_row11_col13, #T_f57c0_row12_col12, #T_f57c0_row12_col13, #T_f57c0_row13_col12, #T_f57c0_row13_col13, #T_f57c0_row14_col12, #T_f57c0_row14_col13, #T_f57c0_row15_col12, #T_f57c0_row15_col13, #T_f57c0_row16_col12, #T_f57c0_row16_col13, #T_f57c0_row17_col12, #T_f57c0_row17_col13, #T_f57c0_row18_col12, #T_f57c0_row18_col13, #T_f57c0_row19_col12, #T_f57c0_row19_col13, #T_f57c0_row20_col12, #T_f57c0_row20_col13, #T_f57c0_row21_col12, #T_f57c0_row21_col13, #T_f57c0_row22_col12, #T_f57c0_row22_col13, #T_f57c0_row23_col7, #T_f57c0_row23_col12, #T_f57c0_row23_col13 {
#   background-color: rgb(165, 89, 0);
# }
# #T_f57c0_row1_col0, #T_f57c0_row16_col7, #T_f57c0_row16_col9 {
#   background-color: rgb(102, 152, 0);
# }
# #T_f57c0_row1_col1, #T_f57c0_row5_col2 {
#   background-color: rgb(119, 135, 0);
# }
# #T_f57c0_row1_col2, #T_f57c0_row1_col6, #T_f57c0_row9_col3, #T_f57c0_row10_col9, #T_f57c0_row17_col8 {
#   background-color: rgb(87, 167, 0);
# }
# #T_f57c0_row1_col3, #T_f57c0_row1_col5 {
#   background-color: rgb(109, 145, 0);
# }
# #T_f57c0_row1_col4, #T_f57c0_row1_col8, #T_f57c0_row14_col5 {
#   background-color: rgb(90, 164, 0);
# }
# #T_f57c0_row1_col7, #T_f57c0_row18_col5 {
#   background-color: rgb(111, 143, 0);
# }
# #T_f57c0_row1_col9, #T_f57c0_row2_col2, #T_f57c0_row2_col4, #T_f57c0_row11_col3, #T_f57c0_row19_col10 {
#   background-color: rgb(106, 148, 0);
# }
# #T_f57c0_row1_col10, #T_f57c0_row12_col5, #T_f57c0_row12_col11, #T_f57c0_row18_col4 {
#   background-color: rgb(86, 168, 0);
# }
# #T_f57c0_row1_col11, #T_f57c0_row3_col4, #T_f57c0_row16_col1, #T_f57c0_row16_col11, #T_f57c0_row18_col3, #T_f57c0_row18_col9 {
#   background-color: rgb(112, 142, 0);
# }
# #T_f57c0_row2_col0 {
#   background-color: rgb(124, 130, 0);
# }
# #T_f57c0_row2_col1, #T_f57c0_row5_col0, #T_f57c0_row5_col7 {
#   background-color: rgb(136, 118, 0);
# }
# #T_f57c0_row2_col3, #T_f57c0_row5_col9 {
#   background-color: rgb(129, 125, 0);
# }
# #T_f57c0_row2_col5, #T_f57c0_row2_col11, #T_f57c0_row5_col8, #T_f57c0_row17_col11 {
#   background-color: rgb(121, 133, 0);
# }
# #T_f57c0_row2_col7, #T_f57c0_row3_col5 {
#   background-color: rgb(123, 131, 0);
# }
# #T_f57c0_row2_col8, #T_f57c0_row17_col7, #T_f57c0_row17_col9 {
#   background-color: rgb(105, 149, 0);
# }
# #T_f57c0_row2_col9, #T_f57c0_row3_col2, #T_f57c0_row5_col6 {
#   background-color: rgb(116, 138, 0);
# }
# #T_f57c0_row2_col10, #T_f57c0_row10_col11, #T_f57c0_row17_col5 {
#   background-color: rgb(99, 155, 0);
# }
# #T_f57c0_row3_col0, #T_f57c0_row4_col0, #T_f57c0_row4_col9 {
#   background-color: rgb(125, 129, 0);
# }
# #T_f57c0_row3_col1, #T_f57c0_row4_col1, #T_f57c0_row17_col1, #T_f57c0_row19_col0, #T_f57c0_row20_col2 {
#   background-color: rgb(137, 117, 0);
# }
# #T_f57c0_row3_col3, #T_f57c0_row5_col5, #T_f57c0_row19_col5 {
#   background-color: rgb(134, 120, 0);
# }
# #T_f57c0_row3_col6, #T_f57c0_row4_col10, #T_f57c0_row15_col1 {
#   background-color: rgb(113, 141, 0);
# }
# #T_f57c0_row3_col7, #T_f57c0_row5_col4 {
#   background-color: rgb(130, 124, 0);
# }
# #T_f57c0_row3_col8, #T_f57c0_row4_col2, #T_f57c0_row4_col4, #T_f57c0_row19_col2, #T_f57c0_row19_col4, #T_f57c0_row19_col6 {
#   background-color: rgb(114, 140, 0);
# }
# #T_f57c0_row3_col9 {
#   background-color: rgb(122, 132, 0);
# }
# #T_f57c0_row3_col10, #T_f57c0_row17_col3, #T_f57c0_row18_col7, #T_f57c0_row18_col11 {
#   background-color: rgb(108, 146, 0);
# }
# #T_f57c0_row3_col11, #T_f57c0_row20_col10 {
#   background-color: rgb(128, 126, 0);
# }
# #T_f57c0_row4_col3, #T_f57c0_row19_col3, #T_f57c0_row19_col7, #T_f57c0_row19_col9 {
#   background-color: rgb(135, 119, 0);
# }
# #T_f57c0_row4_col5 {
#   background-color: rgb(126, 128, 0);
# }
# #T_f57c0_row4_col6 {
#   background-color: rgb(115, 139, 0);
# }
# #T_f57c0_row4_col7, #T_f57c0_row5_col3, #T_f57c0_row19_col11 {
#   background-color: rgb(131, 123, 0);
# }
# #T_f57c0_row4_col8, #T_f57c0_row5_col10 {
#   background-color: rgb(117, 137, 0);
# }
# #T_f57c0_row4_col11 {
#   background-color: rgb(133, 121, 0);
# }
# #T_f57c0_row5_col1 {
#   background-color: rgb(146, 108, 0);
# }
# #T_f57c0_row5_col11 {
#   background-color: rgb(138, 116, 0);
# }
# #T_f57c0_row6_col0, #T_f57c0_row7_col4 {
#   background-color: rgb(48, 206, 0);
# }
# #T_f57c0_row6_col1, #T_f57c0_row7_col5, #T_f57c0_row11_col0, #T_f57c0_row15_col2 {
#   background-color: rgb(71, 183, 0);
# }
# #T_f57c0_row6_col2, #T_f57c0_row6_col4 {
#   background-color: rgb(45, 209, 0);
# }
# #T_f57c0_row6_col3, #T_f57c0_row6_col7, #T_f57c0_row11_col8, #T_f57c0_row13_col0 {
#   background-color: rgb(66, 188, 0);
# }
# #T_f57c0_row6_col5, #T_f57c0_row10_col0, #T_f57c0_row11_col4, #T_f57c0_row14_col2, #T_f57c0_row14_col4 {
#   background-color: rgb(65, 189, 0);
# }
# #T_f57c0_row6_col6, #T_f57c0_row6_col8 {
#   background-color: rgb(47, 207, 0);
# }
# #T_f57c0_row6_col9, #T_f57c0_row14_col6, #T_f57c0_row14_col10 {
#   background-color: rgb(68, 186, 0);
# }
# #T_f57c0_row6_col10 {
#   background-color: rgb(64, 190, 0);
# }
# #T_f57c0_row7_col0, #T_f57c0_row8_col2, #T_f57c0_row12_col2, #T_f57c0_row12_col6 {
#   background-color: rgb(55, 199, 0);
# }
# #T_f57c0_row7_col1, #T_f57c0_row8_col7, #T_f57c0_row10_col5 {
#   background-color: rgb(82, 172, 0);
# }
# #T_f57c0_row7_col2 {
#   background-color: rgb(49, 205, 0);
# }
# #T_f57c0_row7_col6 {
#   background-color: rgb(51, 203, 0);
# }
# #T_f57c0_row7_col7, #T_f57c0_row17_col6 {
#   background-color: rgb(74, 180, 0);
# }
# #T_f57c0_row7_col8, #T_f57c0_row8_col4 {
#   background-color: rgb(52, 202, 0);
# }
# #T_f57c0_row7_col9, #T_f57c0_row11_col10, #T_f57c0_row17_col2 {
#   background-color: rgb(76, 178, 0);
# }
# #T_f57c0_row7_col11, #T_f57c0_row11_col7 {
#   background-color: rgb(98, 156, 0);
# }
# #T_f57c0_row8_col0, #T_f57c0_row8_col8, #T_f57c0_row9_col0, #T_f57c0_row10_col4 {
#   background-color: rgb(56, 198, 0);
# }
# #T_f57c0_row8_col1, #T_f57c0_row12_col9, #T_f57c0_row17_col10 {
#   background-color: rgb(83, 171, 0);
# }
# #T_f57c0_row8_col5, #T_f57c0_row11_col2, #T_f57c0_row15_col0, #T_f57c0_row16_col0, #T_f57c0_row16_col10 {
#   background-color: rgb(77, 177, 0);
# }
# #T_f57c0_row8_col6, #T_f57c0_row12_col4, #T_f57c0_row12_col10 {
#   background-color: rgb(57, 197, 0);
# }
# #T_f57c0_row8_col9, #T_f57c0_row15_col8, #T_f57c0_row18_col6, #T_f57c0_row18_col10 {
#   background-color: rgb(81, 173, 0);
# }
# #T_f57c0_row9_col1, #T_f57c0_row16_col8, #T_f57c0_row18_col2 {
#   background-color: rgb(84, 170, 0);
# }
# #T_f57c0_row9_col2, #T_f57c0_row10_col8 {
#   background-color: rgb(61, 193, 0);
# }
# #T_f

# %% [markdown]
# ## Skill table for linear regression, where skill = 1 - MSE_model / MSE_lr

# %%
skill_table2 = 1 - benchmark_table/benchmark_table["Linear Regression"]
styled_df_2 = skill_table2.style.applymap(color_scale)
styled_df_2
# Out:
# /var/folders/m4/89q121bx0sxd404czvsn99kh0000gn/T/ipykernel_6376/1327961144.py:2: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df_2 = skill_table2.style.applymap(color_scale)
# <style type="text/css">
# #T_ece6a_row0_col0, #T_ece6a_row12_col8 {
#   background-color: rgb(202, 52, 0);
# }
# #T_ece6a_row0_col1, #T_ece6a_row2_col2, #T_ece6a_row3_col2, #T_ece6a_row13_col1, #T_ece6a_row20_col6, #T_ece6a_row23_col2 {
#   background-color: rgb(181, 73, 0);
# }
# #T_ece6a_row0_col2, #T_ece6a_row0_col10, #T_ece6a_row0_col11, #T_ece6a_row1_col10, #T_ece6a_row1_col11, #T_ece6a_row2_col5, #T_ece6a_row2_col10, #T_ece6a_row2_col11, #T_ece6a_row3_col10, #T_ece6a_row3_col11, #T_ece6a_row4_col10, #T_ece6a_row4_col11, #T_ece6a_row5_col10, #T_ece6a_row5_col11, #T_ece6a_row6_col10, #T_ece6a_row6_col11, #T_ece6a_row7_col10, #T_ece6a_row7_col11, #T_ece6a_row8_col10, #T_ece6a_row8_col11, #T_ece6a_row9_col10, #T_ece6a_row9_col11, #T_ece6a_row10_col10, #T_ece6a_row10_col11, #T_ece6a_row11_col10, #T_ece6a_row11_col11, #T_ece6a_row12_col10, #T_ece6a_row12_col11, #T_ece6a_row13_col10, #T_ece6a_row13_col11, #T_ece6a_row14_col10, #T_ece6a_row14_col11, #T_ece6a_row15_col10, #T_ece6a_row15_col11, #T_ece6a_row16_col10, #T_ece6a_row16_col11, #T_ece6a_row17_col10, #T_ece6a_row17_col11, #T_ece6a_row18_col10, #T_ece6a_row18_col11, #T_ece6a_row19_col10, #T_ece6a_row19_col11, #T_ece6a_row20_col10, #T_ece6a_row20_col11, #T_ece6a_row21_col10, #T_ece6a_row21_col11, #T_ece6a_row22_col10, #T_ece6a_row22_col11, #T_ece6a_row23_col10, #T_ece6a_row23_col11 {
#   background-color: rgb(165, 89, 0);
# }
# #T_ece6a_row0_col3, #T_ece6a_row1_col9, #T_ece6a_row3_col9, #T_ece6a_row4_col5, #T_ece6a_row14_col7, #T_ece6a_row14_col9 {
#   background-color: rgb(156, 98, 0);
# }
# #T_ece6a_row0_col4, #T_ece6a_row5_col8, #T_ece6a_row14_col1, #T_ece6a_row19_col3, #T_ece6a_row21_col5, #T_ece6a_row22_col5 {
#   background-color: rgb(171, 83, 0);
# }
# #T_ece6a_row0_col5, #T_ece6a_row0_col6, #T_ece6a_row1_col7, #T_ece6a_row18_col7 {
#   background-color: rgb(164, 90, 0);
# }
# #T_ece6a_row0_col7, #T_ece6a_row5_col5, #T_ece6a_row13_col9, #T_ece6a_row23_col9 {
#   background-color: rgb(160, 94, 0);
# }
# #T_ece6a_row0_col8, #T_ece6a_row12_col1, #T_ece6a_row18_col3, #T_ece6a_row18_col9 {
#   background-color: rgb(172, 82, 0);
# }
# #T_ece6a_row0_col9, #T_ece6a_row5_col9, #T_ece6a_row12_col6, #T_ece6a_row14_col2, #T_ece6a_row15_col7 {
#   background-color: rgb(153, 101, 0);
# }
# #T_ece6a_row1_col0 {
#   background-color: rgb(208, 46, 0);
# }
# #T_ece6a_row1_col1, #T_ece6a_row2_col8, #T_ece6a_row3_col1, #T_ece6a_row20_col2, #T_ece6a_row22_col2 {
#   background-color: rgb(178, 76, 0);
# }
# #T_ece6a_row1_col2, #T_ece6a_row2_col7, #T_ece6a_row3_col7, #T_ece6a_row4_col2, #T_ece6a_row4_col3, #T_ece6a_row5_col2, #T_ece6a_row16_col0, #T_ece6a_row20_col3, #T_ece6a_row20_col5, #T_ece6a_row23_col3 {
#   background-color: rgb(168, 86, 0);
# }
# #T_ece6a_row1_col3, #T_ece6a_row1_col5, #T_ece6a_row15_col6, #T_ece6a_row22_col9 {
#   background-color: rgb(161, 93, 0);
# }
# #T_ece6a_row1_col4, #T_ece6a_row3_col8, #T_ece6a_row21_col2, #T_ece6a_row23_col4 {
#   background-color: rgb(176, 78, 0);
# }
# #T_ece6a_row1_col6, #T_ece6a_row4_col6, #T_ece6a_row20_col7 {
#   background-color: rgb(169, 85, 0);
# }
# #T_ece6a_row1_col8, #T_ece6a_row2_col3, #T_ece6a_row17_col8, #T_ece6a_row21_col1, #T_ece6a_row22_col8, #T_ece6a_row23_col8 {
#   background-color: rgb(177, 77, 0);
# }
# #T_ece6a_row2_col0 {
#   background-color: rgb(218, 36, 0);
# }
# #T_ece6a_row2_col1 {
#   background-color: rgb(188, 66, 0);
# }
# #T_ece6a_row2_col4, #T_ece6a_row18_col4, #T_ece6a_row19_col2, #T_ece6a_row19_col6 {
#   background-color: rgb(180, 74, 0);
# }
# #T_ece6a_row2_col6, #T_ece6a_row5_col1, #T_ece6a_row15_col1 {
#   background-color: rgb(175, 79, 0);
# }
# #T_ece6a_row2_col9, #T_ece6a_row11_col1, #T_ece6a_row15_col2 {
#   background-color: rgb(158, 96, 0);
# }
# #T_ece6a_row3_col0 {
#   background-color: rgb(197, 57, 0);
# }
# #T_ece6a_row3_col3, #T_ece6a_row4_col8, #T_ece6a_row22_col1 {
#   background-color: rgb(173, 81, 0);
# }
# #T_ece6a_row3_col4, #T_ece6a_row3_col6, #T_ece6a_row14_col0, #T_ece6a_row18_col2, #T_ece6a_row21_col7 {
#   background-color: rgb(174, 80, 0);
# }
# #T_ece6a_row3_col5, #T_ece6a_row23_col7 {
#   background-color: rgb(159, 95, 0);
# }
# #T_ece6a_row4_col0, #T_ece6a_row5_col4, #T_ece6a_row20_col4 {
#   background-color: rgb(186, 68, 0);
# }
# #T_ece6a_row4_col1, #T_ece6a_row11_col3, #T_ece6a_row13_col4, #T_ece6a_row18_col5, #T_ece6a_row19_col5, #T_ece6a_row19_col7, #T_ece6a_row19_col9, #T_ece6a_row23_col1 {
#   background-color: rgb(170, 84, 0);
# }
# #T_ece6a_row4_col4, #T_ece6a_row12_col0, #T_ece6a_row21_col3, #T_ece6a_row23_col6 {
#   background-color: rgb(167, 87, 0);
# }
# #T_ece6a_row4_col7, #T_ece6a_row21_col9 {
#   background-color: rgb(163, 91, 0);
# }
# #T_ece6a_row4_col9, #T_ece6a_row15_col4, #T_ece6a_row22_col7 {
#   background-color: rgb(155, 99, 0);
# }
# #T_ece6a_row5_col0 {
#   background-color: rgb(196, 58, 0);
# }
# #T_ece6a_row5_col3, #T_ece6a_row12_col9, #T_ece6a_row22_col6 {
#   background-color: rgb(157, 97, 0);
# }
# #T_ece6a_row5_col6, #T_ece6a_row5_col7, #T_ece6a_row12_col4, #T_ece6a_row13_col6, #T_ece6a_row23_col5 {
#   background-color: rgb(162, 92, 0);
# }
# #T_ece6a_row6_col0 {
#   background-color: rgb(87, 167, 0);
# }
# #T_ece6a_row6_col1 {
#   background-color: rgb(117, 137, 0);
# }
# #T_ece6a_row6_col2 {
#   background-color: rgb(74, 180, 0);
# }
# #T_ece6a_row6_col3, #T_ece6a_row8_col2, #T_ece6a_row10_col4 {
#   background-color: rgb(104, 150, 0);
# }
# #T_ece6a_row6_col4 {
#   background-color: rgb(72, 182, 0);
# }
# #T_ece6a_row6_col5, #T_ece6a_row9_col4 {
#   background-color: rgb(103, 151, 0);
# }
# #T_ece6a_row6_col6, #T_ece6a_row7_col2 {
#   background-color: rgb(81, 173, 0);
# }
# #T_ece6a_row6_col7 {
#   background-color: rgb(106, 148, 0);
# }
# #T_ece6a_row6_col8 {
#   background-color: rgb(82, 172, 0);
# }
# #T_ece6a_row6_col9, #T_ece6a_row7_col3, #T_ece6a_row8_col0, #T_ece6a_row8_col8 {
#   background-color: rgb(110, 144, 0);
# }
# #T_ece6a_row7_col0 {
#   background-color: rgb(105, 149, 0);
# }
# #T_ece6a_row7_col1, #T_ece6a_row8_col9, #T_ece6a_row9_col5, #T_ece6a_row10_col5, #T_ece6a_row10_col6, #T_ece6a_row11_col8 {
#   background-color: rgb(131, 123, 0);
# }
# #T_ece6a_row7_col4 {
#   background-color: rgb(79, 175, 0);
# }
# #T_ece6a_row7_col5 {
#   background-color: rgb(107, 147, 0);
# }
# #T_ece6a_row7_col6, #T_ece6a_row8_col4 {
#   background-color: rgb(92, 162, 0);
# }
# #T_ece6a_row7_col7, #T_ece6a_row8_col6 {
#   background-color: rgb(115, 139, 0);
# }
# #T_ece6a_row7_col8 {
#   background-color: rgb(94, 160, 0);
# }
# #T_ece6a_row7_col9 {
#   background-color: rgb(118, 136, 0);
# }
# #T_ece6a_row8_col1 {
#   background-color: rgb(134, 120, 0);
# }
# #T_ece6a_row8_col3, #T_ece6a_row11_col4 {
#   background-color: rgb(128, 126, 0);
# }
# #T_ece6a_row8_col5, #T_ece6a_row9_col8, #T_ece6a_row10_col2 {
#   background-color: rgb(121, 133, 0);
# }
# #T_ece6a_row8_col7 {
#   background-color: rgb(133, 121, 0);
# }
# #T_ece6a_row9_col0 {
#   background-color: rgb(111, 143, 0);
# }
# #T_ece6a_row9_col1, #T_ece6a_row9_col6, #T_ece6a_row16_col5 {
#   background-color: rgb(138, 116, 0);
# }
# #T_ece6a_row9_col2 {
#   background-color: rgb(127, 127, 0);
# }
# #T_ece6a_row9_col3, #T_ece6a_row14_col3, #T_ece6a_row17_col2, #T_ece6a_row17_col3 {
#   background-color: rgb(146, 108, 0);
# }
# #T_ece6a_row9_col7, #T_ece6a_row15_col3 {
#   background-color: rgb(147, 107, 0);
# }
# #T_ece6a_row9_col9 {
#   background-color: rgb(140, 114, 0);
# }
# #T_ece6a_row10_col0 {
#   background-color: rgb(137, 117, 0);
# }
# #T_ece6a_row10_col1, #T_ece6a_row13_col5, #T_ece6a_row15_col9, #T_ece6a_row16_col4 {
#   background-color: rgb(152, 102, 0);
# }
# #T_ece6a_row10_col3, #T_ece6a_row12_col3 {
#   background-color: rgb(143, 111, 0);
# }
# #T_ece6a_row10_col7, #T_ece6a_row13_col3, #T_ece6a_row15_col5 {
#   background-color: rgb(145, 109, 0);
# }
# #T_ece6a_row10_col8 {
#   background-color: rgb(123, 131, 0);
# }
# #T_ece6a_row10_col9, #T_ece6a_row17_col7, #T_ece6a_row17_col9 {
#   background-color: rgb(141, 113, 0);
# }
# #T_ece6a_row11_col0, #T_ece6a_row16_col7 {
#   background-color: rgb(148, 106, 0);
# }
# #T_ece6a_row11_col2, #T_ece6a_row12_col5, #T_ece6a_row14_col6, #T_ece6a_row16_col1, #T_ece6a_row18_col6, #T_ece6a_row20_col9, #T_ece6a_row22_col3 {
#   background-color: rgb(166, 88, 0);
# }
# #T_ece6a_row11_col5, #T_ece6a_row13_col2, #T_ece6a_row16_col6 {
#   background-color: rgb(151, 1

# %% [markdown]
# ## Epochs and time needed for training

# %%
epoch_time_table
# Out:
# Model          Autoformer           Informer           Transformer            \
# Metric             epochs time[min]   epochs time[min]      epochs time[min]
# Target Horizon
# multi  24             7.0         9      8.0         6         4.0         3
#        48             4.0         5      5.0         4         4.0         3
#        96             4.0         6      4.0         4         4.0         3
#        192            5.0        10      5.0         6         4.0         4
#        336            5.0        12      4.0         5         4.0         5
#        720            4.0        16      6.0        11         5.0        12
# load   24            10.0        13      9.0         7         8.0         5
#        48             8.0        10     10.0         8         5.0         3
#        96             8.0        12     10.0        10         6.0         4
#        192            8.0        15      9.0        10         5.0         5
#        336            5.0        12      6.0         8         4.0         5
#        720            6.0        24      4.0         8         4.0        10
# solar  24             9.0        11     10.0         8         5.0         3
#        48             4.0         5     10.0         8         6.0         4
#        96             7.0        11      9.0         9         4.0         3
#        192            9.0        17      7.0         8         5.0         5
#        336            7.0        17      6.0         8         4.0         5
#        720            6.0        23      4.0         8         4.0         9
# wind   24             5.0         6      5.0         4         4.0         3
#        48             4.0         5      5.0         4         4.0         3
#        96             4.0         6      5.0         5         4.0         3
#        192            6.0        11      5.0         5         4.0         4
#        336            4.0        10      5.0         7         4.0         5
#        720            4.0        15      4.0         7         4.0         9
#
# Model            LSTM           XGBoost           Linear Regression
# Metric         epochs time[min]  epochs time[min]            epochs time[min]
# Target Horizon
# multi  24         4.0         1     NaN         0               NaN         0
#        48         4.0         1     NaN         0               NaN         0
#        96         4.0         2     NaN         1               NaN         0
#        192        4.0         2     NaN         2               NaN         0
#        336        5.0         3     NaN         3               NaN         0
#        720        4.0         3     NaN         7               NaN         0
# load   24         9.0         4     NaN         0               NaN         0
#        48         5.0         2     NaN         0               NaN         0
#        96         4.0         2     NaN         0               NaN         0
#        192        5.0         3     NaN         1               NaN         0
#        336        6.0         3     NaN         1               NaN         0
#        720        4.0         2     NaN         2               NaN         0
# solar  24         6.0         2     NaN         0               NaN         0
#        48         6.0         2     NaN         0               NaN         0
#        96         5.0         3     NaN         0               NaN         0
#        192        4.0         2     NaN         1               NaN         0
#        336        5.0         3     NaN         1               NaN         0
#        720        4.0         2     NaN         2               NaN         0
# wind   24         4.0         2     NaN         0               NaN         0
#        48         4.0         1     NaN         0               NaN         0
#        96         4.0         2     NaN         0               NaN         0
#        192        4.0         2     NaN         0               NaN         0
#        336        4.0         2     NaN         1               NaN         0
#        720        4.0         2     NaN         2               NaN         0

# %% [markdown]
# ## Average of columns of benchmarks for MSE and MAE

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot Average MSE in the first subplot
benchmark_table_with_dummy.xs('MSE', level=1, axis=1).plot(kind="box", title="Average MSE", ax=axes[0], showmeans=True, meanline=True)
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45)

# Plot Average MAE in the second subplot
benchmark_table_with_dummy.xs('MAE', level=1, axis=1).plot(kind="box", title="Average MAE", ax=axes[1], showmeans=True, meanline=True)
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=45) 

plt.tight_layout()
plt.show()

# %% [markdown]
# Dashed line is the mean </br> </br>
# Solid line is the median

# %% [markdown]
# ## MSE - horizon plot for each target

# %%
bms = []
bms_et = []
for target in targets:
    bm = benchmark_table.xs(target, level=0, axis=0)
    bm_mse = bm.xs('MSE', level=1, axis=1)
    bm_mae = bm.xs('MAE', level=1, axis=1)
    bms.append((bm_mse, bm_mae))

    bm_et = epoch_time_table.xs(target, level=0, axis=0)
    bm_e = bm_et.xs('epochs', level=1, axis=1)
    bm_t = bm_et.xs('time[min]', level=1, axis=1)
    bms_et.append((bm_e, bm_t))

# %%
fig, ax = plt.subplots(2, 2, figsize=(6, 6))
# Define a list of colors for each model
colors = ["#1f77b4", "#17becf", "#2ca02c", "#d62728", "#ff7f0e", "#9467bd", "#7f7f7f"] # purple: 
#colors= ["#1f77b4", "#17becf", "#2ca02c", "#e377c2","#bcbd22", "#7f7f7f"]

for i, (bm_mse, bm_mae) in enumerate(bms):
    row, col = divmod(i, 2)
    #print(bm_mse.shape)
    #print(len(colors))
    #ax[row][col].plot(bm_mse, color=colors)
    for j in range(bm_mse.shape[1]):  # Iterate over the columns of bm_mse
        #print(bm_mse.shape)
        #print(type(bm_mse))
        ax[row][col].plot(bm_mse.iloc[:, j], color=colors[j])
    ax[row][col].set_title('MSE ' + targets[i])
fig.legend(models[:-1], loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=4)
fig.tight_layout()

# %% [markdown]
# ## MSE - train_time plot for each target and each horizon

# %%
import numpy as np


# For each target
for i, ((bm_mse, bm_mae),(bm_e, bm_t)) in enumerate(zip(bms, bms_et)):
    
    # For each horizon: Plot mse vs time for all models
    fig, ax = plt.subplots(2,3, figsize=(8, 6))
    for j, horizon in enumerate(horizons):
        row, col = divmod(j, 3)
        ax[row][col].scatter(bm_t.iloc[j].values, bm_mse.iloc[j].values, c=colors[:-1])
        ax[row][col].set_title('MSE ' + targets[i] + ', horizon ' + horizons[j])
        ax[row][col].set_xlabel('Time [min]')
        ax[row][col].set_ylabel('MSE')
    fig.tight_layout()
    #fig.legend(models[:-1], loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=4)
