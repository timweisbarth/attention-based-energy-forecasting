# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from datetime import timedelta

df1 = pd.read_csv("../data/raw/Actual_consumption_2015_2023_Hour.csv", sep=";")
df2 = pd.read_csv("../data/raw/Actual_generation_2015_2023_Hour.csv", sep=";")

# %% [markdown]
# ## First look

# %%
df1.describe()
# Out:
#                 Date     Start      End  \
# count          78888     78888    78888
# unique          3287        24       24
# top     Oct 30, 2016  12:00 AM  1:00 AM
# freq              25      3287     3287
#
#        Total (grid load) [MWh] Calculated resolutions  \
# count                                           78888
# unique                                          61122
# top                                            45,937
# freq                                                7
#
#        Residual load [MWh] Calculated resolutions  \
# count                                       78888
# unique                                      64320
# top                                     44,232.75
# freq                                            6
#
#        Hydro pumped storage [MWh] Calculated resolutions
# count                                              78888
# unique                                             18888
# top                                                    0
# freq                                                 579

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78888 entries, 0 to 78887
# Data columns (total 6 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Date                                               78888 non-null  object
#  1   Start                                              78888 non-null  object
#  2   End                                                78888 non-null  object
#  3   Total (grid load) [MWh] Calculated resolutions     78888 non-null  object
#  4   Residual load [MWh] Calculated resolutions         78888 non-null  object
#  5   Hydro pumped storage [MWh] Calculated resolutions  78888 non-null  object
# dtypes: object(6)
# memory usage: 3.6+ MB

# %%
df1.head()
# Out:
#           Date     Start      End  \
# 0  Jan 1, 2015  12:00 AM  1:00 AM
# 1  Jan 1, 2015   1:00 AM  2:00 AM
# 2  Jan 1, 2015   2:00 AM  3:00 AM
# 3  Jan 1, 2015   3:00 AM  4:00 AM
# 4  Jan 1, 2015   4:00 AM  5:00 AM
#
#   Total (grid load) [MWh] Calculated resolutions  \
# 0                                      44,600.25
# 1                                      43,454.75
# 2                                      41,963.25
# 3                                      40,617.75
# 4                                      39,936.75
#
#   Residual load [MWh] Calculated resolutions  \
# 0                                  35,955.75
# 1                                     34,641
# 2                                  32,909.25
# 3                                     31,548
# 4                                   30,773.5
#
#   Hydro pumped storage [MWh] Calculated resolutions
# 0                                             601.5
# 1                                            346.25
# 2                                            521.75
# 3                                          1,228.25
# 4                                           1,821.5

# %%
df1["date"] = pd.to_datetime(df1['Date'] + ' ' + df1['Start'], format='%b %d, %Y %I:%M %p')
df1 = df1.drop(columns=["Date", "Start", "End"])
df1 = df1.rename(columns={"Total (grid load) [MWh] Calculated resolutions": "load"})
df1 = df1[["date"] + ["load"]]
df1["load"] = df1["load"].str.replace(',', '').astype(float)
df1
# Out:
#                      date      load
# 0     2015-01-01 00:00:00  44600.25
# 1     2015-01-01 01:00:00  43454.75
# 2     2015-01-01 02:00:00  41963.25
# 3     2015-01-01 03:00:00  40617.75
# 4     2015-01-01 04:00:00  39936.75
# ...                   ...       ...
# 78883 2023-12-31 19:00:00  48792.75
# 78884 2023-12-31 20:00:00  45698.50
# 78885 2023-12-31 21:00:00  43818.00
# 78886 2023-12-31 22:00:00  42893.50
# 78887 2023-12-31 23:00:00  41471.75
#
# [78888 rows x 2 columns]

# %%
df2.describe()
# Out:
#        Other renewable [MWh] Calculated resolutions
# count                                  78888.000000
# mean                                     160.197530
# std                                       41.079289
# min                                       50.250000
# 25%                                      131.000000
# 50%                                      157.000000
# 75%                                      191.000000
# max                                      260.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78888 entries, 0 to 78887
# Data columns (total 15 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Date                                               78888 non-null  object
#  1   Start                                              78888 non-null  object
#  2   End                                                78888 non-null  object
#  3   Biomass [MWh] Calculated resolutions               78888 non-null  object
#  4   Hydropower [MWh] Calculated resolutions            78888 non-null  object
#  5   Wind offshore [MWh] Calculated resolutions         78888 non-null  object
#  6   Wind onshore [MWh] Calculated resolutions          78888 non-null  object
#  7   Photovoltaics [MWh] Calculated resolutions         78888 non-null  object
#  8   Other renewable [MWh] Calculated resolutions       78888 non-null  float64
#  9   Nuclear [MWh] Calculated resolutions               78888 non-null  object
#  10  Lignite [MWh] Calculated resolutions               78888 non-null  object
#  11  Hard coal [MWh] Calculated resolutions             78888 non-null  object
#  12  Fossil gas [MWh] Calculated resolutions            78888 non-null  object
#  13  Hydro pumped storage [MWh] Calculated resolutions  78888 non-null  object
#  14  Other conventional [MWh] Calculated resolutions    78888 non-null  object
# dtypes: float64(1), object(14)
# memory usage: 9.0+ MB

# %%
df2.head()
# Out:
#           Date     Start      End Biomass [MWh] Calculated resolutions  \
# 0  Jan 1, 2015  12:00 AM  1:00 AM                             4,024.25
# 1  Jan 1, 2015   1:00 AM  2:00 AM                             3,982.75
# 2  Jan 1, 2015   2:00 AM  3:00 AM                              4,019.5
# 3  Jan 1, 2015   3:00 AM  4:00 AM                             4,040.75
# 4  Jan 1, 2015   4:00 AM  5:00 AM                             4,037.75
#
#   Hydropower [MWh] Calculated resolutions  \
# 0                                1,158.25
# 1                                   1,188
# 2                                1,139.25
# 3                                 1,122.5
# 4                                   1,112
#
#   Wind offshore [MWh] Calculated resolutions  \
# 0                                      516.5
# 1                                     516.25
# 2                                        514
# 3                                     517.75
# 4                                     519.75
#
#   Wind onshore [MWh] Calculated resolutions  \
# 0                                     8,128
# 1                                   8,297.5
# 2                                     8,540
# 3                                     8,552
# 4                                   8,643.5
#
#   Photovoltaics [MWh] Calculated resolutions  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    Other renewable [MWh] Calculated resolutions  \
# 0                                         133.0
# 1                                         122.5
# 2                                          93.0
# 3                                          86.5
# 4                                          86.5
#
#   Nuclear [MWh] Calculated resolutions Lignite [MWh] Calculated resolutions  \
# 0                             10,710.5                            15,687.25
# 1                            11,086.25                            15,321.75
# 2                            11,026.25                             14,817.5
# 3                            11,027.75                               14,075
# 4                            10,962.25                               14,115
#
#   Hard coal [MWh] Calculated resolutions  \
# 0                               3,219.75
# 1                               2,351.25
# 2                                  2,227
# 3                               2,339.75
# 4                                2,461.5
#
#   Fossil gas [MWh] Calculated resolutions  \
# 0                                1,226.25
# 1                                  870.75
# 2                                   809.5
# 3                                     821
# 4                                  831.25
#
#   Hydro pumped storage [MWh] Calculated resolutions  \
# 0                                          1,525.75
# 1                                          1,079.25
# 2                                               787
# 3                                            287.75
# 4                                            346.75
#
#   Other conventional [MWh] Calculated resolutions
# 0                                        4,909.25
# 1                                        4,932.75
# 2                                        5,041.75
# 3                                           5,084
# 4                                        5,070.75

# %%
df2["date"] = pd.to_datetime(df2['Date'] + ' ' + df2['Start'], format='%b %d, %Y %I:%M %p')
df2 = df2.drop(columns=["Date", "Start", "End"])
df2["wind_gen"] = df2["Wind offshore [MWh] Calculated resolutions"].str.replace(',', '').astype(float) + df2["Wind onshore [MWh] Calculated resolutions"].str.replace(',', '').astype(float)
df2 = df2.rename(columns={"Photovoltaics [MWh] Calculated resolutions": "solar_gen", "Hydro pumped storage [MWh] Calculated resolutions": "hydro_storage_gen"})
df2 = df2[["date", "wind_gen", "solar_gen"]]
df2["solar_gen"] = df2["solar_gen"].str.replace(',', '').astype(float)
#df2["hydro_storage_gen"] = df2["hydro_storage_gen"].str.replace(',', '').astype(float)

# %%
df2 = df2.drop(columns=("date"))
df = pd.concat((df1, df2), axis=1)

#Convert to UTC time
df['date'] = df['date'].dt.tz_localize('Europe/Berlin', ambiguous='infer').dt.tz_convert('UTC')

# Convert to permanent utc+1 which is cet winter time.
df['date'] =  df['date'] + timedelta(hours=1) 
df
# Out:
#                            date      load  wind_gen  solar_gen
# 0     2015-01-01 00:00:00+00:00  44600.25   8644.50        0.0
# 1     2015-01-01 01:00:00+00:00  43454.75   8813.75        0.0
# 2     2015-01-01 02:00:00+00:00  41963.25   9054.00        0.0
# 3     2015-01-01 03:00:00+00:00  40617.75   9069.75        0.0
# 4     2015-01-01 04:00:00+00:00  39936.75   9163.25        0.0
# ...                         ...       ...       ...        ...
# 78883 2023-12-31 19:00:00+00:00  48792.75  35267.00        0.0
# 78884 2023-12-31 20:00:00+00:00  45698.50  36010.00        0.0
# 78885 2023-12-31 21:00:00+00:00  43818.00  35827.75        0.0
# 78886 2023-12-31 22:00:00+00:00  42893.50  35882.25        0.0
# 78887 2023-12-31 23:00:00+00:00  41471.75  35866.75        0.0
#
# [78888 rows x 4 columns]

# %%
df.to_csv("./../data/preproc_non_deepl/smard_data.csv", index=False)
df.to_csv("./../data/raw/smard_data.csv", index=False)
df.to_csv("./../data/preproc/smard_data.csv", index=False)
df.describe()
#494 TWh pro Jahr
# Out:
#                load      wind_gen     solar_gen
# count  78888.000000  78888.000000  78888.000000
# mean   56350.076875  12685.801804   4961.652653
# std    10002.022918   9862.947669   7743.748810
# min    30909.000000     81.500000      0.000000
# 25%    48122.625000   4914.437500      0.000000
# 50%    56035.875000   9893.125000    147.500000
# 75%    64684.000000  18139.062500   7768.875000
# max    81077.500000  52856.250000  40673.750000

# %%
df[:50400].describe()
# Out:
#                load      wind_gen     solar_gen
# count  50400.000000  50400.000000  50400.000000
# mean   56992.048358  11567.422937   4561.652569
# std    10127.488946   9075.524517   6936.166480
# min    33047.250000     81.500000      0.000000
# 25%    48512.437500   4501.625000      0.000000
# 50%    56669.000000   9031.125000    172.000000
# 75%    65664.187500  16178.687500   7327.125000
# max    79938.500000  45909.250000  32947.250000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78888 entries, 0 to 78887
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       78888 non-null  datetime64[ns, UTC]
#  1   load       78888 non-null  float64
#  2   wind_gen   78888 non-null  float64
#  3   solar_gen  78888 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(3)
# memory usage: 2.4 MB

# %%
df_cropped = df[49000:50000]
df_cropped.head(30)
# Out:
#                            date      load  wind_gen  solar_gen
# 49000 2020-08-03 16:00:00+00:00  57065.25   4174.50    7724.00
# 49001 2020-08-03 17:00:00+00:00  56857.75   4423.00    4793.75
# 49002 2020-08-03 18:00:00+00:00  56067.50   4197.50    2187.75
# 49003 2020-08-03 19:00:00+00:00  54212.00   3678.75     421.25
# 49004 2020-08-03 20:00:00+00:00  52430.50   3884.00       3.25
# 49005 2020-08-03 21:00:00+00:00  49200.50   4286.25       0.00
# 49006 2020-08-03 22:00:00+00:00  44933.25   4304.25       0.00
# 49007 2020-08-03 23:00:00+00:00  42203.75   4240.00       0.00
# 49008 2020-08-04 00:00:00+00:00  40838.00   4689.50       0.00
# 49009 2020-08-04 01:00:00+00:00  39984.00   4953.25       0.00
# 49010 2020-08-04 02:00:00+00:00  40027.25   4698.75       0.00
# 49011 2020-08-04 03:00:00+00:00  41022.50   4434.00       0.00
# 49012 2020-08-04 04:00:00+00:00  43936.00   4283.00      16.75
# 49013 2020-08-04 05:00:00+00:00  49485.50   4113.50     612.50
# 49014 2020-08-04 06:00:00+00:00  54610.00   3333.50    3047.25
# 49015 2020-08-04 07:00:00+00:00  58145.50   2145.50    7142.00
# 49016 2020-08-04 08:00:00+00:00  59523.25   1676.00   11631.25
# 49017 2020-08-04 09:00:00+00:00  61012.25   2044.25   15059.50
# 49018 2020-08-04 10:00:00+00:00  62132.25   2773.50   17194.25
# 49019 2020-08-04 11:00:00+00:00  61783.00   3699.00   17608.25
# 49020 2020-08-04 12:00:00+00:00  60894.75   4146.00   17247.50
# 49021 2020-08-04 13:00:00+00:00  59403.75   4194.00   16392.75
# 49022 2020-08-04 14:00:00+00:00  58514.00   4097.75   14949.25
# 49023 2020-08-04 15:00:00+00:00  57362.00   3965.25   13008.25
# 49024 2020-08-04 16:00:00+00:00  57069.00   3311.25   10592.50
# 49025 2020-08-04 17:00:00+00:00  56836.25   2942.50    6817.25
# 49026 2020-08-04 18:00:00+00:00  55920.00   2484.50    2858.50
# 49027 2020-08-04 19:00:00+00:00  53652.00   2063.25     476.75
# 49028 2020-08-04 20:00:00+00:00  52027.00   2258.00       1.50
# 49029 2020-08-04 21:00:00+00:00  48772.25   2978.25       0.00

# %%
# plot different time series
skip_days = 14
skip_hours = 24*skip_days

keys = list(df.drop(columns="date").columns)
print(keys)
labels = keys

fig, axs = plt.subplots(4,1, figsize=(25,10), dpi=100)

for i, (key, label) in enumerate(zip(keys, labels)):
    axs[i].plot(df_cropped['date'], df_cropped[key], label=label)
    #axs[i].set_xticks(np.array(list(df_cropped['date']))[::skip_hours])
    axs[i].legend()
# Out:
# ['load', 'wind_gen', 'solar_gen']

# %%
# plot 
means = df["wind_gen"].groupby(df["date"].dt.year).mean()
plt.plot(means)

# %%
# plot
means = df["solar_gen"].groupby(df["date"].dt.year).mean()
plt.plot(means)

# %%
means = df["load"].groupby(df["date"].dt.year).mean()
plt.plot(means)

# %%
#means = df["hydro_storage_gen"].groupby(df["date"].dt.year).mean()
#plt.plot(means)

# %%
# plot
means_solar = df["solar_gen"].groupby(df["date"].dt.month).mean()
means_wind = df["wind_gen"].groupby(df["date"].dt.month).mean()

plt.plot(means_solar, label="solar")
plt.plot(means_wind, label="wind")
plt.plot(means_solar+means_wind, label="total")
plt.legend()

# Dunkelflaute in autumn (less sun but not yet a lot of wind)

# %%
means_load = df["load"].groupby(df["date"].dt.month).mean()
plt.plot(means_load, label="load")

# %%
#means = df["hydro_storage_gen"].groupby(df["date"].dt.month).mean()
#plt.plot(means)

# %%
means_load = df["load"].groupby(df["date"].dt.isocalendar().week).mean()
plt.plot(means_load, label="load")

# %%
means_load = df["load"].groupby(df["date"].dt.dayofweek).mean()
plt.plot(means_load, label="load")

# %%
means_load = df["load"].groupby(df["date"].dt.hour).mean()
plt.plot(means_load, label="load")
